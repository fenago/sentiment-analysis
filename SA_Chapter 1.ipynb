# %%
# !pip install tweepy

# %%
# import tweepy
import tweepy as tw

# your Twitter API key and API secret
my_api_key = "doDU8P0NSf9q8qKbFrrhpdkFC"
my_api_secret = "XDEHsfRi3BZt57hmFawaEatHdiAiBQDWtXJ9XomSH1wH5sHSUR"

# %%
# authenticate
auth = tw.OAuthHandler(my_api_key, my_api_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
search_query = "#DeltaVariant+covid19 -filter:retweets"

# %%
# get tweets from the API
tweets = tw.Cursor(api.search,
              q=search_query,
              lang="en",
              since="2020-09-16",).items(10)

# %%
print(tweets)

# %%
# store the API responses in a list
tweets_copy = []
for tweet in tweets:
    tweets_copy.append(tweet)
    
print("Total Tweets fetched:", len(tweets_copy))
# Out:
# Total Tweets fetched: 10

# %%
# get tweets from the API
tweets = tw.Cursor(api.search,
              q=search_query,
              lang="en",
              since="2020-09-16").items(5)
user_locs = [[tweet.user.screen_name, tweet.user.location] for tweet in tweets]

user_locs
# Out:
# [['NickOtaWang', 'Denver, CO'],
#  ['TanNguyenDEXCL', 'Melbourne, Victoria'],
#  ['Mv999999', 'Bengaluru, India'],
#  ['NarayanIndia1', 'Maharashtra,  India'],
#  ['mrstealyourwig1', '']]

# %%
# get tweets from the API
tweets = tw.Cursor(api.search,
              q=search_query,
              lang="en",
              since="2020-09-16").items(10000)
user_locs = [[tweet.user.id, tweet.user.location, 
              tweet.created_at, tweet.user.description] for tweet in tweets]

# %%
import pandas as pd
tweet_text = pd.DataFrame(data=user_locs, columns=['UserId',
                                                   'location','TweetAt', 'OriginalTweet'])
tweet_text.head()
# Out:
#                 UserId  ...                                      OriginalTweet
# 0           1148018994  ...  #Historian, MA candidate in #History, MA in #H...
# 1   781322576807260160  ...             PhD Candidate, Deakin Health Economics
# 2  1350684597412003840  ...  वने रणे शत्रुजलाग्निमध्ये\nमहार्णवे पर्वतमस्तक...
# 3  1247445958700331008  ...  Engineer based in Maharashtra. Born and grew i...
# 4   725677732919689216  ...  Comedian/Producer/Manager/Uncomfortabletruthli...
#
# [5 rows x 4 columns]

# %%
tweet_text.shape
# Out:
# (882, 4)

# %%
tweet_text.to_csv('twitter.csv')
